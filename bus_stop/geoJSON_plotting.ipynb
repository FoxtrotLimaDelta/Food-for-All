# %%
import geojson

# %%
with open('resources/bus_stop.geojson') as f:
    gf = geojson.load(f)
features = gf['features'][0]

# %%
features
# Out:
# {"geometry": {"coordinates": [-111.823076, 33.414719], "type": "Point"}, "properties": {"ADA": "No", "ATIS_ID": 5196.0, "Bathroom": "No", "Bench": 1.0, "BikeRack": 0.0, "BusBay": "No", "DateUpdated": 1541147907453.0, "Direction": "Southbound", "Em_Call": "No", "Info_Display": "No", "Juris": "Mesa", "Lat": 33.4147193304186, "Lighting": "No", "Location": "MESA DR & MAIN ST", "Long": -111.823075990545, "NextRide": 16020.0, "OBJECTID": 1, "Photo": "https://farm9.staticflickr.com/8719/16921707206_868c4c2c60_o.jpg", "PublicArt": "No", "Routes": "120", "Shelter": 1.0, "Sidewalk": null, "StopID": 5182.0, "TrashCan": 0.0, "Type_": "Standard", "WaterFountain": "No"}, "type": "Feature"}

# %%
import geopandas as gpd
import fiona

# %%
gdf = gpd.read_file(r'resources/bus_stop.geojson')

# %%
gdf
# Out:
#       OBJECTID  StopID  NextRide                 Location       Juris  \
# 0            1  5182.0   16020.0        MESA DR & MAIN ST        Mesa
# 1            2  2982.0   16001.0        MESA DR & MAIN ST        Mesa
# 2            3  4681.0   16016.0         MESA DR & 6TH ST        Mesa
# 3            4  4682.0   16017.0  MESA DR & UNIVERSITY DR        Mesa
# 4            5  4679.0   16019.0         MESA DR & 1ST ST        Mesa
# ...        ...     ...       ...                      ...         ...
# 7659      7802   657.0   15650.0      Shea Bl & Via Linda  Scottsdale
# 7660      7803   628.0   15652.0       Shea Bl & 114th St  Scottsdale
# 7661      7804  5874.0   15665.0       Shea Bl & 136th St  Scottsdale
# 7662      7805   631.0   16919.0       Shea Bl & 136th St  Scottsdale
# 7663      7806  9750.0   16980.0    Indian Bend & 86th St  Scottsdale
#
#       Shelter  Bench  TrashCan BusBay  BikeRack  ...     Type_   DateUpdated  \
# ...

# %%
import matplotlib as plot

# %%
phoenix_gpd = gpd[gpd['Juris']=='Phoenix']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1ca9c533d083> in <module>
# ----> 1 phoenix_gpd = gpd[gpd['Juris']=='Phoenix']
#
# TypeError: 'module' object is not subscriptable
