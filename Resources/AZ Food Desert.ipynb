# %%
#Dependencies 
import os
import csv

import pandas as pd

# %%
# Path to collect data from the Resources folder
foodAccessData_csv = os.path.join('Resources', 'AZ Food Access Research Atlas.csv')

# %%
# Read in the CSV file
with open(foodAccessData_csv) as csvfile:

    # Split the data on commas
    csvreader = csv.reader(csvfile, delimiter=',')

# %%
# Use Pandas to read data
food_access_df = pd.read_csv(foodAccessData_csv)
food_access_df.head(100)
# Out:
#     CensusTract    State  County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0    4001942600  Arizona  Apache      0     1578      447                  0
# 1    4001942700  Arizona  Apache      0     5628     1700                  0
# 2    4001944000  Arizona  Apache      0     6043     1821                  0
# 3    4001944100  Arizona  Apache      0     5870     1632                  0
# 4    4001944201  Arizona  Apache      0     4010     1146                  0
# ..          ...      ...     ...    ...      ...      ...                ...
# 95   4009961202  Arizona  Graham      0     3609     1248                  0
# 96   4009961300  Arizona  Graham      1     3409     1271                  0
# 97   4009961400  Arizona  Graham      1     4947     1696                  0
# 98   4009961500  Arizona  Graham      0     4449     1509                  0
# 99   4009961600  Arizona  Graham      0     3161      394                  1
#
# ...

# %% [markdown]
# Section below is example code I can edit & use to narrow my df to Maricopa county only.

# %%
# Create a new DataFrame that looks into a specific county
maricopa_food_access_df = food_access_df.loc[food_access_df["County"] == "Maricopa"]
maricopa_food_access_df
# Out:
#       CensusTract    State    County  Urban  POP2010  OHU2010  \
# 113    4013010101  Arizona  Maricopa      0     5073     2246
# 114    4013010102  Arizona  Maricopa      1     4640     2041
# 115    4013030401  Arizona  Maricopa      1     4283     2008
# 116    4013030402  Arizona  Maricopa      1     3895     1706
# 117    4013040502  Arizona  Maricopa      1     4861     2188
# ...           ...      ...       ...    ...      ...      ...
# 1024   4013980100  Arizona  Maricopa      0        0        0
# 1025   4013980400  Arizona  Maricopa      1       15        5
# 1026   4013980500  Arizona  Maricopa      0        0        0
# 1027   4013980600  Arizona  Maricopa      0        0        0
# 1028   4013980700  Arizona  Maricopa      0        4        2
#
#       GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 113                   0         0  0.000000                  0  ...
# 114                   0         0  0.000000                  0  ...
# ...

# %%
# Dependencies
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# %%
# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float

# %%
#pgAdmin password, postgress port, database name hidden in config file
from config import pswrd, port, sql

# %%
# Create engine using the `FoodForAll.postgres` database file
engine = create_engine(f'postgresql://postgres:{pswrd}@localhost:{port}/{sql}')

# %%
#make sure this table doesn't exist already in the DB
maricopa_food_access_df.to_sql('desert_data', engine, if_exists='replace')

# %%
# Path to collect data from the Resources folder
snap_csv = os.path.join('Resources', 'snap.csv')

# %%
# Read in the CSV file
with open(snap_csv) as csvfile:

    # Split the data on commas
    csvreader = csv.reader(csvfile, delimiter=',')

# %%
# Use Pandas to read data
snap_df = pd.read_csv(snap_csv)
snap_df.head(100)
# Out:
#     Unnamed: 0               Store_Name                     Address  \
# 0           42         Kwik Corner 5059            5059 W Olive Ave
# 1          120        Grand Ave Produce           8990 W Windsor Dr
# 2          524       Big Az Market  2 2          51348 W Highway 60
# 3          549          Pride Food Mart          1734 E Apache Blvd
# 4          627          Caribbean Oasis              2958 N 16th St
# ..         ...                      ...                         ...
# 95        8957            Speedway 3004      JUNCTION HWY 160 & 163
# 96        9113         Circle K 2723410  2275 S Buffalo Soldier Trl
# 97        9210     Corner Store 2741665           10335 E Drexel Rd
# 98        9337       Family Dollar 8644          4239 W McDowell Rd
# 99        9403  Pilot Travel Center 611            6700 W Latham St
#
#    Address_Line__2          City State   Zip5    Zip4    County  Longitude  \
# ...

# %%
# Create a new DataFrame that looks into a specific county
snap_df = snap_df.loc[snap_df["County"] == "Maricopa"]
snap_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Store_Name, Address, Address_Line__2, City, State, Zip5, Zip4, County, Longitude, Latitude, ObjectId, FIPS, Census Tract]
# Index: []

# %%
# Path to collect data from the Resources folder
bs_csv = os.path.join('Resources', 'bs.csv')

# %%
# Read in the CSV file
with open(bs_csv) as csvfile:

    # Split the data on commas
    csvreader = csv.reader(csvfile, delimiter=',')

# %%
# Use Pandas to read data
bus_df = pd.read_csv(bs_csv)
bus_df.head(100)
# Out:
#     Unnamed: 0  OBJECTID  StopID  NextRide                      Location  \
# 0            0       1.0  5182.0   16020.0             MESA DR & MAIN ST
# 1            1       2.0  2982.0   16001.0             MESA DR & MAIN ST
# 2            2       3.0  4681.0   16016.0              MESA DR & 6TH ST
# 3            3       4.0  4682.0   16017.0       MESA DR & UNIVERSITY DR
# 4            4       5.0  4679.0   16019.0              MESA DR & 1ST ST
# ..         ...       ...     ...       ...                           ...
# 95          95     110.0  2895.0   16206.0    GILBERT RD & UNIVERSITY DR
# 96          96     111.0  4722.0   16746.0       POWER RD & INGLEWOOD ST
# 97          97     112.0  9110.0   10038.0  S GILBERT RD & E FAIRVIEW ST
# 98          98     113.0  3032.0   16738.0      POWER RD & UNIVERSITY DR
# 99          99     114.0  5220.0   12579.0       POWER RD & SOUTHERN AVE
#
#       Juris  Shelter  Bench  TrashCan BusBay  ...   DateUpdated Sidewalk  \
# ...

# %%
# Create engine using the `FoodForAll.postgres` database file
engine = create_engine(f'postgresql://postgres:{pswrd}@localhost:{port}/{sql}')

# %%
# Path to collect data from the Resources folder
lr_csv = os.path.join('Resources', 'lr.csv')

# %%
# Read in the CSV file
with open(lr_csv) as csvfile:

    # Split the data on commas
    csvreader = csv.reader(csvfile, delimiter=',')

# %%
# Use Pandas to read data
lrail_df = pd.read_csv(lr_csv)
lrail_df.head(100)
# Out:
#     Unnamed: 0  OBJECTID  StationId                    StationName  \
# 0            0         1          1    19th Avenue / Dunlap Avenue
# 1            1         2         35    Center Street / Main Street
# 2            2         3          2  19th Avenue / Northern Avenue
# 3            3         4          3  19th Avenue / Glendale Avenue
# 4            4         5         21       44th Street / Washington
# ..         ...       ...        ...                            ...
# 83          83        87         16         Jefferson / 1st Avenue
# 84          84        88         36       Mesa Drive / Main Street
# 85          85        89         22       50th St / Washington St
# 86          86        90         37           Main St / Stapley Dr
# 87          87        91         38           Main St / Gilbert Rd
#
#    Jurisdiction StationStatus     POINT_X    POINT_Y  \
# 0       Phoenix  In Operation -112.099389  33.567090
# 1          Mesa  In Operation -111.830660  33.415098
# ...

# %%
#make sure this table doesn't exist already in the DB
bus_df.to_sql('bus_data', engine, if_exists='replace')

# %%
# Create engine using the `FoodForAll.postgres` database file
engine = create_engine(f'postgresql://postgres:{pswrd}@localhost:{port}/{sql}')

# %%
#make sure this table doesn't exist already in the DB
lrail_df.to_sql('lrail_data', engine, if_exists='replace')

# %% [markdown]
# Creating Matplotlip charts - hopefully

# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
